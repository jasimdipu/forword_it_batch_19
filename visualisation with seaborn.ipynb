# %%
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill', y='tip', data=tips)

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='sex')

# %%
tips['sex'][tips['sex'] == 'Male'].count()
# Out:
# 157

# %%
tips['sex'][tips['sex'] == 'Female'].count()
# Out:
# 87

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='smoker')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='sex', style='smoker')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='sex', style='smoker', col='smoker')

# %%
sorted(tips['size'].unique())
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='sex', style='smoker', col='smoker', size='size')

# %%
sns.relplot(x='total_bill', y='tip', data=tips, hue='sex', style='smoker', col='size', size='size', col_wrap=2)

# %%
sns.scatterplot(x='day', y='tip', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# "strip", "swarm", "box", "violin",
#     "boxen", "point", "bar", or "count"

# %%
sns.catplot(x='day', y='tip', data=tips)

# %%
sns.catplot(x='day', y='tip', data=tips, kind='swarm')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='day', y='tip', data=tips, kind='swarm', hue='size')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='day', y='tip', data=tips, kind='box')

# %%
sns.catplot(x='day', y='tip', data=tips, kind='box', hue='size')

# %%
sns.catplot(x='day', y='tip', data=tips, kind='violin')

# %%
sns.catplot(x='day', y='tip', data=tips, kind='violin', hue='smoker')

# %%
sns.catplot(x='day', y='tip', data=tips, kind='boxen')

# %%
sns.catplot(x='day', y='tip', data=tips, kind='point')

# %%
sns.catplot(x='day', y='tip', data=tips, kind='bar')

# %%
sns.catplot(x='size', data=tips, kind='count')

# %%
sns.pairplot(data=tips)
